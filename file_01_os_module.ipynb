# %%
import os

# %%
# print(dir(os))

# %%
# current directory

print(os.getcwd())
# Out:
# /content

# %%
# change directory

os.chdir('..')
print(os.getcwd())
# Out:
# /

# %%
# get files and folders

print(sorted(os.listdir(), reverse=True))
# Out:
# ['var', 'usr', 'tools', 'tmp', 'sys', 'srv', 'sbin', 'run', 'root', 'python-apt.tar.xz', 'python-apt', 'proc', 'opt', 'mnt', 'media', 'libx32', 'lib64', 'lib32', 'lib', 'kaggle', 'home', 'etc', 'dev', 'datalab', 'cuda-keyring_1.1-1_all.deb', 'content', 'boot', 'bin', 'NGC-DL-CONTAINER-LICENSE', '.dockerenv']

# %%
print(os.listdir('/content'))
# Out:
# ['.config', 'sample_data']

# %% [markdown]
# #### Home directory

# %%
print(os.environ.get('HOME'))
# Out:
# /root

# %% [markdown]
# #### Create and delete folder(s)

# %%
from genericpath import exists
# create a single-level folder

os.chdir('/content')
os.mkdir('shallow folder')

# %%
# create multi-level folders

os.makedirs('deep folder/subfolder/sub-subfolder', exist_ok=True)

# %%
# delete folders

# without deleting intermediare directory
os.rmdir('deep folder/subfolder/sub-subfolder')

# %%
# also deleting intermediare directory
os.removedirs('deep folder/subfolder')

# %% [markdown]
# #### Renaming

# %%
# original name first, new name second

os.chdir('/content')
os.rename('shallow folder', 'shallower folder')

# %% [markdown]
# #### Directory tree

# %%
# os.walk is a generator
for dirpath, dirnames, filenames in os.walk('/content'):
  print('Current path:', dirpath)
  print('Directories:', dirnames)
  print('Files,', filenames)
  print()
# Out:
# Current path: /content
# Directories: ['.config', 'shallower folder', 'sample_data']
# Files, []
#
# Current path: /content/.config
# Directories: ['configurations', 'logs']
# Files, ['active_config', 'hidden_gcloud_config_universe_descriptor_data_cache_configs.db', '.last_survey_prompt.yaml', 'default_configs.db', '.last_update_check.json', '.last_opt_in_prompt.yaml', 'config_sentinel', 'gce']
#
# Current path: /content/.config/configurations
# Directories: []
# Files, ['config_default']
#
# Current path: /content/.config/logs
# Directories: ['2025.06.18']
# Files, []
#
# Current path: /content/.config/logs/2025.06.18
# Directories: []
# Files, ['13.35.24.200491.log', '13.35.04.842247.log', '13.35.23.496398.log', '13.35.15.114113.log', '13.34.36.370420.log', '13.35.13.517345.log']
#
# Current path: /content/shallower folder
# Directories: []
# Files, []
#
# Current path: /content/sample_data
# Directories: []
# Files, ['anscombe.json', 'README.md', 'california_housing_test.csv', 'mnist_train_small.csv', 'mnist_test.csv', 'california_housing_train.csv']

# %% [markdown]
# #### Creating path

# %%
file_path = os.path.join('/content', 'test.txt')
print(file_path)
# Out:
# /content/test.txt

# %%
with open(file_path, 'w') as f:
  f.write('hello')

# %%
# need to use string interpolation to run a shell command
# !cat {file_path}
# Out:
# hello

# %% [markdown]
# #### Check whether path exists

# %%
print(os.path.exists('/content/test_1.txt'))
# Out:
# False

# %%
print(os.path.exists('/content/test.txt'))
# Out:
# True

# %%
print(os.path.isdir('/content'))
# Out:
# True

# %%
print(os.path.isfile('/content/test.txt'))
# Out:
# True

# %% [markdown]
# #### Split root path and extension

# %%
print(os.path.splitext('/content/some_folder/test.txt'))
# Out:
# ('/content/some_folder/test', '.txt')

# %% [markdown]
# #### Get basename, dirname

# %%
print(os.path.basename('/content/some_folder/test'))
# Out:
# test

# %%
print(os.path.dirname('/content/some_folder/test.txt'))
# Out:
# /content/some_folder
